# %% [markdown]
# # **Mètodos de Texto**
#
# En python nosotros podemos hacer uso de varios metodos para el manejo de strings
#
# o cadenas de caracteres, en el caso de pandas usasmos los mismos mètodos pero de una manera diferente
#
# pandas_object.**str**.**metodo**

# %%
import pandas as pd

# %%
email = 'anndykint@gmail.com'

# %%
email.split('@')
# Out:
# ['anndykint', 'gmail.com']

# %%
name = pd.Series(['Andrew', 'George', 'Olivia', 'Bob', 'Clarie', '19'])

# %%
name
# Out:
# 0    Andrew
# 1    George
# 2    Olivia
# 3       Bob
# 4    Clarie
# 5        19
# dtype: object

# %%
name.str.upper()
# Out:
# 0    ANDREW
# 1    GEORGE
# 2    OLIVIA
# 3       BOB
# 4    CLARIE
# 5        19
# dtype: object

# %%
name.str.isdigit()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool

# %% [markdown]
# ## **Texto a Columnas**

# %%
tech_finance = ['GOOG, AMZN, APPL', 'JPM, BAC, GS']

# %%
tickers = pd.Series(tech_finance)

# %%
tickers
# Out:
# 0    GOOG, AMZN, APPL
# 1        JPM, BAC, GS
# dtype: object

# %%
tickers.str.split(',', expand=True)
# Out:
#       0      1      2
# 0  GOOG   AMZN   APPL
# 1   JPM    BAC     GS

# %% [markdown]
# ## **Extraer substring**

# %%
name
# Out:
# 0    Andrew
# 1    George
# 2    Olivia
# 3       Bob
# 4    Clarie
# 5        19
# dtype: object

# %%
# extraer elementos desde la izquierda
name.str[:3]
# Out:
# 0    And
# 1    Geo
# 2    Oli
# 3    Bob
# 4    Cla
# 5     19
# dtype: object

# %%
# extraer elementos desde la derecha
name.str[-3:]
# Out:
# 0    rew
# 1    rge
# 2    via
# 3    Bob
# 4    rie
# 5     19
# dtype: object

# %%
# extrear elementos con indice especifico
name.str.slice(2, 4) # el ultimo indice no se toma en cuenta
# Out:
# 0    dr
# 1    or
# 2    iv
# 3     b
# 4    ar
# 5
# dtype: object

# %%
messy_names = pd.Series(['andrew', '    bo;bo', 'clarie'])

# %%
messy_names
# Out:
# 0       andrew
# 1        bo;bo
# 2       clarie
# dtype: object

# %%
messy_names.str.replace(';', '').str.strip().str.capitalize()
# Out:
# 0    Andrew
# 1      Bobo
# 2    Clarie
# dtype: object

# %%
def cleanup(name):
    name = name.replace(';', '')
    name = name.strip()
    name = name.capitalize()
    return name

# %%
messy_names.apply(cleanup)
# Out:
# 0    Andrew
# 1      Bobo
# 2    Clarie
# dtype: object
